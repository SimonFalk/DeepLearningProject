# %%
from tqdm.notebook import tqdm
from data_wrangling.datamanager import DataLoader
import numpy as np
import pandas as pd
import pickle
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ### Multichannel.

# %%
# # Load data
# dl = DataLoader()
# data = dl.get_fcx2(['s1'])

# # Basic preprocessing
# X1 = data['s1']['data']
# mn = X1.mean(0).reshape((1, -1))
# st = X1.std (0).reshape((1, -1))
# X1 = (X1 - mn) / st

# # Data organization
# fs = 1000
# idxs_train_test_split = int(len(X1) * 0.7)
# p_in  = 100
# p_out = 10
# step  = 15

# idxs_train = np.arange(0, idxs_train_test_split - p_out - p_in, step)

# X = np.stack([
#     X1[idx : idx + p_in]
#     for idx in idxs_train
# ])

# Y = np.stack([
#     X1[idx + p_in : idx + p_in + p_out]
#     for idx in idxs_train
# ])

# np.save('idxs_train_test_split', idxs_train_test_split)
# np.save('X1', X1)
# np.save('X', X)
# np.save('Y', Y)
    
# del data
# del X1
# del X
# del Y
# del idxs_train
# del mn
# del st

# %% [markdown]
# ### Spectrogram.

# %%
# # Load data
# dl = DataLoader()
# data = dl.get_fcx2(['s1'])

# # Basic preprocessing
# f, fi, t, X1 = data['s1']['spectrogram'](0, noverlap = 99, nfft = 2 ** 8)

# # Data organization
# fs = 1000
# idxs_train_test_split = int(len(X1) * 0.7)
# p_in  = 100
# p_out = 10
# step  = 15

# idxs_train = np.arange(0, idxs_train_test_split - p_out - p_in, step)

# X = np.stack([
#     X1[idx : idx + p_in]
#     for idx in idxs_train
# ])

# Y = np.stack([
#     X1[idx + p_in : idx + p_in + p_out]
#     for idx in idxs_train
# ])

# np.save('idxs_train_test_split', idxs_train_test_split)
# np.save('X1', X1)
# np.save('X', X)
# np.save('Y', Y)
    
# print(X1.shape, X.shape, Y.shape)
    
# del data
# del X1
# del X
# del Y
# del idxs_train

# %%
params_1 = []
for depth_pre in [1, 2]:
    for width in [64, 128]:
        for depth_post in [1, 2]:
            for dropout in [0, 0.3]:
                params_1.append((
                    depth_pre,
                    width,
                    width * 2,
                    depth_post,
                    width,
                    dropout
                ))
len(params_1)
# Out:
# 16

# %%
params_2 = []
for depth_pre in [1, 2, 3]:
    for width in [64, 128]:
        for depth_post in [0, 1]:
            for dropout in [0, 0.3]:
                params_2.append((
                    depth_pre,
                    width,
                    depth_post,
                    width,
                    dropout
                ))
len(params_2)
# Out:
# 24

# %%
params_3 = []
for depth_pre in [1, 2]:
    for width in [64, 128]:
        for depth_post in [1, 2]:
            for dropout in [0, 0.3]:
                params_3.append((
                    depth_pre,
                    width,
                    depth_post,
                    width,
                    dropout
                ))
len(params_3)
# Out:
# 16

# %%
# for idx, (
#     depth_pre,
#     width_pre,
#     width_mid,
#     depth_post,
#     width_post,
#     dropout
# ) in tqdm(enumerate(params_1)):
#     !python3 batch_test-1.py $depth_pre $width_pre $width_mid $depth_post $width_post $dropout $idx

# %%
# for idx, (
#     depth_pre,
#     width_pre,
#     depth_post,
#     width_post,
#     dropout
# ) in tqdm(enumerate(params_2)):
#     !python3 batch_test-2.py $depth_pre $width_pre $depth_post $width_post $dropout $idx

# %%
# for idx, (
#     depth_pre,
#     width_pre,
#     depth_post,
#     width_post,
#     dropout
# ) in tqdm(enumerate(params_3)):
#     !python3 batch_test-3.py $depth_pre $width_pre $depth_post $width_post $dropout $idx

# %%
# !rm X.npy
# !rm Y.npy
# !rm X1.npy
# !rm idxs_train_test_split.npy

# %%
dirs = [
    'results_batch_test_1',
    'results_batch_test_2',
    'results_batch_test_3',
    'results_batch_test_1-ms',
    'results_batch_test_2-ms',
    'results_batch_test_3-ms',
]

ress = [
    os.listdir(d)
    for d in dirs
]

def unpickle(f):
    with open(f, 'rb') as fp:
        obj = pickle.load(fp)
    return obj

ress = [
    [
        unpickle(f'{d}/{f}')
        for f in lst
    ]
    for d, lst in zip(dirs, ress)
]

# %%
mses = [
    np.array([
        np.array(r['mse']).mean()
        for r in res
    ])
    for res in ress
]

# %%
labels = [
    'A1 Spectrogram',
    'A2 Spectrogram',
    'A3 Spectrogram',
    'A1 Multichannel',
    'A2 Multichannel',
    'A3 Multichannel',
]

cols = 3
rows = 2
fig = plt.figure(figsize = (7 * cols, 5 * rows))
axes = [plt.subplot(rows, cols, idx + 1) for idx in range(6)]

for mse, ax, lab in zip(mses, axes, labels):
    ax.bar(np.arange(len(mse)), mse)
    ax.plot(
        [-0.5, len(mse) - 0.5], 
        [np.percentile(mse, 25), np.percentile(mse, 25)], 
        linewidth = 1, 
        c = 'black'
    )
    ax.set_ylim(0, 0.2)
    ax.set_title(lab)
plt.show()

# %%
best = [
    np.min(lst)
    for lst in mses
]
best
# Out:
# [0.09475187027781178,
#  0.09767757985348648,
#  0.09730340277182023,
#  0.06603186629779002,
#  0.06243457680745417,
#  0.06257990887242335]

# %%
df1 = pd.DataFrame(params_1, columns = [
    'depth_pre',
    'width_pre',
    'width_mid',
    'depth_post',
    'width_post',
    'dropout'
])

df1['mses'] = mses[3]

df1.sort_values('mses')
# Out:
#     depth_pre  width_pre  width_mid  depth_post  width_post  dropout      mses
# 2           1         64        128           2          64      0.0  0.066032
# 10          2         64        128           2          64      0.0  0.066656
# 12          2        128        256           1         128      0.0  0.069911
# 11          2         64        128           2          64      0.3  0.070876
# 15          2        128        256           2         128      0.3  0.072097
# 7           1        128        256           2         128      0.3  0.072728
# 0           1         64        128           1          64      0.0  0.072958
# 5           1        128        256           1         128      0.3  0.085815
# 6           1        128        256           2         128      0.0  0.105938
# 14          2        128        256           2         128      0.0  0.106039
# 1           1         64        128           1          64      0.3  0.106294
# 3           1         64        128           2          64      0.3  0.106364
# 9           2         64        128           1          64      0.3  0.106545
# 4           1        128        256           1         128      0.0  0.106714
# 8           2         64        128           1          64      0.0  0.112103
# 13          2        128        256           1         128      0.3  0.112440

# %%
df2 = pd.DataFrame(params_2, columns = [
    'depth_pre',
    'width_pre',
    'depth_post',
    'width_post',
    'dropout'
])

df2['mses'] = mses[4]

df2.sort_values('mses')
# Out:
#     depth_pre  width_pre  depth_post  width_post  dropout      mses
# 17          3         64           0          64      0.3  0.062435
# 23          3        128           1         128      0.3  0.066075
# 3           1         64           1          64      0.3  0.066309
# 20          3        128           0         128      0.0  0.074236
# 12          2        128           0         128      0.0  0.074979
# 21          3        128           0         128      0.3  0.075556
# 6           1        128           1         128      0.0  0.079013
# 18          3         64           1          64      0.0  0.087799
# 5           1        128           0         128      0.3  0.089628
# 19          3         64           1          64      0.3  0.090274
# 9           2         64           0          64      0.3  0.094461
# 4           1        128           0         128      0.0  0.094853
# 8           2         64           0          64      0.0  0.097885
# 0           1         64           0          64      0.0  0.098522
# 13          2        128           0         128      0.3  0.099767
# 7           1        128           1         128      0.3  0.102768
# 1           1         64           0          64      0.3  0.123555
# 14          2        128           1         128      0.0  0.125857
# 15          2        128           1         128      0.3  0.126003
# 2           1         64           1          64      0.0  0.128779
# 10          2         64           1          64      0.0  0.136044
# 22          3        128           1         128      0.0  0.148711
# 16          3         64           0          64      0.0  0.151642
# 11          2         64           1          64      0.3  0.152063

# %%
df3 = pd.DataFrame(params_3, columns = [
    'depth_pre',
    'width_pre',
    'depth_post',
    'width_post',
    'dropout'
])

df3['mses'] = mses[5]

df3.sort_values('mses')
# Out:
#     depth_pre  width_pre  depth_post  width_post  dropout      mses
# 7           1        128           2         128      0.3  0.062580
# 2           1         64           2          64      0.0  0.063741
# 13          2        128           1         128      0.3  0.064524
# 14          2        128           2         128      0.0  0.065941
# 8           2         64           1          64      0.0  0.066845
# 3           1         64           2          64      0.3  0.067138
# 4           1        128           1         128      0.0  0.069700
# 11          2         64           2          64      0.3  0.075702
# 5           1        128           1         128      0.3  0.092663
# 0           1         64           1          64      0.0  0.093524
# 12          2        128           1         128      0.0  0.094441
# 9           2         64           1          64      0.3  0.097349
# 6           1        128           2         128      0.0  0.098181
# 1           1         64           1          64      0.3  0.098365
# 15          2        128           2         128      0.3  0.100412
# 10          2         64           2          64      0.0  0.102928

# %%
for t_in in [100, 200]:
    for t_out in [10, 20, 50, 100]:
        for architecture in [1, 2, 3]:

            # !python3 batch-ms-mc.py $t_in $t_out $architecture
# Out:
# 2021-05-12 22:43:17.759229: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#
#
#
# 100 - 10 - 1
#
#
#
# 2021-05-12 22:43:48.423265: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-12 22:43:48.423834: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-05-12 22:43:48.455086: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:43:48.455496: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: GeForce GTX 1080 computeCapability: 6.1
# coreClock: 1.797GHz coreCount: 20 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 298.32GiB/s
# 2021-05-12 22:43:48.455533: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-12 22:43:48.457502: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-05-12 22:43:48.457563: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-05-12 22:43:48.458378: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-05-12 22:43:48.458580: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-05-12 22:43:48.460404: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-05-12 22:43:48.460820: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-05-12 22:43:48.460962: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-05-12 22:43:48.461054: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:43:48.461411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:43:48.461736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-05-12 22:43:48.461951: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-05-12 22:43:48.462242: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-12 22:43:48.462346: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:43:48.462662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: GeForce GTX 1080 computeCapability: 6.1
# coreClock: 1.797GHz coreCount: 20 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 298.32GiB/s
# 2021-05-12 22:43:48.462695: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-12 22:43:48.462708: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-05-12 22:43:48.462731: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-05-12 22:43:48.462757: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-05-12 22:43:48.462769: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-05-12 22:43:48.462792: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-05-12 22:43:48.462819: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-05-12 22:43:48.462830: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-05-12 22:43:48.462894: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:43:48.463203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:43:48.463483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-05-12 22:43:48.463506: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-12 22:43:48.796688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-12 22:43:48.796711: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-05-12 22:43:48.796730: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-05-12 22:43:48.796893: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:43:48.797207: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:43:48.797512: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:43:48.797798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7300 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080, pci bus id: 0000:03:00.0, compute capability: 6.1)
# Traceback (most recent call last):
#   File "batch-ms-mc.py", line 158, in <module>
#     repeater = layers.RepeatVector(t_out)(encoder)
#   File "/home/gustav/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py", line 952, in __call__
#     input_list)
#   File "/home/gustav/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1091, in _functional_construction_call
#     inputs, input_masks, args, kwargs)
#   File "/home/gustav/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py", line 822, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "/home/gustav/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py", line 862, in _infer_output_signature
#     self._maybe_build(inputs)
#   File "/home/gustav/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2685, in _maybe_build
#     self.input_spec, inputs, self.name)
#   File "/home/gustav/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/input_spec.py", line 223, in assert_input_compatibility
#     str(tuple(shape)))
# ValueError: Input 0 of layer repeat_vector is incompatible with the layer: expected ndim=2, found ndim=3. Full shape received: (None, 100, 128)
# 2021-05-12 22:43:50.334672: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#
#
#
# 100 - 10 - 2
#
#
#
# 2021-05-12 22:44:20.952010: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-12 22:44:20.952584: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-05-12 22:44:20.983226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:44:20.983608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: GeForce GTX 1080 computeCapability: 6.1
# coreClock: 1.797GHz coreCount: 20 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 298.32GiB/s
# 2021-05-12 22:44:20.983661: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-12 22:44:20.985641: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-05-12 22:44:20.985703: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-05-12 22:44:20.986506: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-05-12 22:44:20.986718: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-05-12 22:44:20.988582: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-05-12 22:44:20.989051: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-05-12 22:44:20.989165: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-05-12 22:44:20.989243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:44:20.989609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:44:20.989963: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-05-12 22:44:20.990198: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-05-12 22:44:20.990488: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-12 22:44:20.990605: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:44:20.990899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:03:00.0 name: GeForce GTX 1080 computeCapability: 6.1
# coreClock: 1.797GHz coreCount: 20 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 298.32GiB/s
# 2021-05-12 22:44:20.990918: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-12 22:44:20.990931: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-05-12 22:44:20.990945: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-05-12 22:44:20.990957: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-05-12 22:44:20.990969: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-05-12 22:44:20.990982: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-05-12 22:44:20.990994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-05-12 22:44:20.991007: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-05-12 22:44:20.991044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:44:20.991350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:44:20.991625: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-05-12 22:44:20.991651: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-12 22:44:21.321665: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-12 22:44:21.321705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-05-12 22:44:21.321709: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-05-12 22:44:21.321875: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:44:21.322227: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:44:21.322627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 22:44:21.322880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7300 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080, pci bus id: 0000:03:00.0, compute capability: 6.1)
# 2021-05-12 22:44:22.362733: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-05-12 22:44:22.382411: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3699850000 Hz
# Epoch 1/100
# 2021-05-12 22:44:26.122910: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-05-12 22:44:26.293975: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-05-12 22:44:26.343152: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 100/100 [==============================] - 34s 292ms/step - loss: 0.4141 - val_loss: 0.2472
# Epoch 2/100
# 100/100 [==============================] - 27s 276ms/step - loss: 0.2335 - val_loss: 0.2023
# Epoch 3/100
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1970 - val_loss: 0.1770
# Epoch 4/100
# 100/100 [==============================] - 27s 276ms/step - loss: 0.1796 - val_loss: 0.1619
# Epoch 5/100
# 100/100 [==============================] - 28s 276ms/step - loss: 0.1666 - val_loss: 0.1531
# Epoch 6/100
# 100/100 [==============================] - 28s 276ms/step - loss: 0.1589 - val_loss: 0.1440
# Epoch 7/100
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1519 - val_loss: 0.1393
# Epoch 8/100
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1473 - val_loss: 0.1320
# Epoch 9/100
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1439 - val_loss: 0.1296
# Epoch 10/100
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1395 - val_loss: 0.1260
# Epoch 11/100
# 100/100 [==============================] - 28s 276ms/step - loss: 0.1369 - val_loss: 0.1249
# Epoch 12/100
# 100/100 [==============================] - 27s 276ms/step - loss: 0.1337 - val_loss: 0.1217
# Epoch 13/100
# 100/100 [==============================] - 27s 276ms/step - loss: 0.1332 - val_loss: 0.1208
# Epoch 14/100
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1299 - val_loss: 0.1168
# Epoch 15/100
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1282 - val_loss: 0.1141
# Epoch 16/100
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1266 - val_loss: 0.1158
# Epoch 17/100
# 100/100 [==============================] - 27s 276ms/step - loss: 0.1261 - val_loss: 0.1124
# Epoch 18/100
# 100/100 [==============================] - 28s 276ms/step - loss: 0.1237 - val_loss: 0.1128
# Epoch 19/100
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1236 - val_loss: 0.1115
# Epoch 1/100
# 300/300 [==============================] - 26s 87ms/step - loss: 0.1349 - val_loss: 0.1179
# Epoch 2/100
# 300/300 [==============================] - 26s 87ms/step - loss: 0.1259 - val_loss: 0.1135
# Epoch 3/100
# 300/300 [==============================] - 26s 87ms/step - loss: 0.1235 - val_loss: 0.1148
# Epoch 4/100
# 300/300 [==============================] - 26s 87ms/step - loss: 0.1218 - val_loss: 0.1102
# Epoch 5/100
# 300/300 [==============================] - 26s 87ms/step - loss: 0.1200 - val_loss: 0.1103
# Epoch 6/100
# 300/300 [==============================] - 26s 87ms/step - loss: 0.
100
# 300/300 [==============================] - 50s 168ms/step - loss: 0.3034 - val_loss: 0.4188
# Epoch 7/100
# 300/300 [==============================] - 50s 168ms/step - loss: 0.2978 - val_loss: 0.4145
# Epoch 8/100
# 300/300 [==============================] - 50s 168ms/step - loss: 0.2936 - val_loss: 0.4044
# Epoch 9/100
# 300/300 [==============================] - 50s 168ms/step - loss: 0.2872 - val_loss: 0.4080
# Epoch 10/100
# 300/300 [==============================] - 50s 168ms/step - loss: 0.2841 - val_loss: 0.4116
# Epoch 11/100
# 300/300 [==============================] - 50s 168ms/step - loss: 0.2817 - val_loss: 0.4142
# 1000/1000 [==============================] - 392s 391ms/step - loss: 0.4215
#
#
#
# 200 - 100 - 3

# %%
ress = []
files = !ls results_batch_ms_mc
files = [f'results_batch_ms_mc/{f}' for f in files]

for f in files:
    with open(f, 'rb') as fp:
        ress.append(pickle.load(fp))

# %%
test_params = [
    f.replace('results_batch_ms_mc/res-', '').replace('.pickle', '').split('-')
    for f in files
]

df = pd.DataFrame(np.concatenate([
    np.array(test_params).astype('int'),
    np.array([r['mse'] for r in ress]).reshape((-1, 1))
], 1), columns = [
    't_in',
    't_out',
    'architecture',
    'mse'
])

# %%
df[df['architecture'] == 1].sort_values('mse')
# Out:
#      t_in  t_out  architecture       mse
# 3   100.0   10.0           1.0  0.076200
# 15  200.0   10.0           1.0  0.081303
# 6   100.0   20.0           1.0  0.139472
# 18  200.0   20.0           1.0  0.169528
# 9   100.0   50.0           1.0  0.280629
# 21  200.0   50.0           1.0  0.291721
# 12  200.0  100.0           1.0  0.399540
# 0   100.0  100.0           1.0  0.405000

# %%
df[df['architecture'] == 2].sort_values('mse')
# Out:
#      t_in  t_out  architecture       mse
# 16  200.0   10.0           2.0  0.107026
# 4   100.0   10.0           2.0  0.112920
# 19  200.0   20.0           2.0  0.166522
# 7   100.0   20.0           2.0  0.169992
# 22  200.0   50.0           2.0  0.307084
# 10  100.0   50.0           2.0  0.310755
# 1   100.0  100.0           2.0  0.434983
# 13  200.0  100.0           2.0  0.441969

# %%
df[df['architecture'] == 3].sort_values('mse')
# Out:
#      t_in  t_out  architecture       mse
# 17  200.0   10.0           3.0  0.085058
# 5   100.0   10.0           3.0  0.086803
# 20  200.0   20.0           3.0  0.148079
# 8   100.0   20.0           3.0  0.151805
# 23  200.0   50.0           3.0  0.295284
# 11  100.0   50.0           3.0  0.297479
# 2   100.0  100.0           3.0  0.419777
# 14  200.0  100.0           3.0  0.421484

# %%
lossess = []
for res in ress:
    losses = []
    for lt in ['loss', 'val_loss']:
        losses.append(np.concatenate([
            res['hists'][0][lt],
            res['hists'][1][lt]
        ]))
    lossess.append(losses)

# %%
rows = 4
cols = 6
plt.figure(figsize = (6 * cols, 4 * rows))
plt.subplots_adjust(hspace = 0.25)
axes = [plt.subplot(rows, cols, idx + 1) for idx in range(len(lossess))]
for (
    ax, 
    losses, 
    (t_in, t_out, architecture, mse)
) in zip(
    axes, 
    lossess, 
    df.values
):
    ax.set_ylim(0.05, 0.75)
    ax.plot(losses[0])
    ax.plot(losses[1])
    ax.set_title(f'{int(t_in)} -> {int(t_out)}, {int(architecture)}, {round(mse, 3)}, {int(place)}')
plt.show()
